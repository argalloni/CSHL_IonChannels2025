# %% [markdown]
# # Evoked Excitatory Postsynaptic Currents (EPSCs)

# %% [markdown]
# #### **Basic instructions:**
# #### 1. **To run code windows/blocks:**
#
#     - you can either hit the play button to the left of the code window
#
#     - or you can use they keyboard shortcut: select the block and press 'shift-enter'.
#
# #### 2. The first time you run this code notebook, you will get a popup asking to choose which version of Python to use (the python "kernel"). **Choose the python kernel called "CSHL_IonChannels"**
#
#     - If you did it correctly, you should see "CSHL_IonChannels (Python 3.11.13)" in the top right of the screen.
#
# #### 3. Make sure you data (.abf) files are in the "data" folder here on the left. You can just copy/paste the files from where they are saved on your computer.

# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import *
update_plot_defaults()

# %% [markdown]
# ## 1. Choose the data file you want to analyze
#
# #### Put the .abf files with your Ih recordings in the "data/Synaptic_currents" folder

# %%
data_folder = "data/7-Synaptic_currents"

from glob import glob
data_files = glob(data_folder+"/*.abf")
print(data_folder)
data_files
# Out:
# data/7-Synaptic_currents
# ['data/7-Synaptic_currents/2025_06_13_0008.abf',
#  'data/7-Synaptic_currents/2025_06_13_0020.abf',
#  'data/7-Synaptic_currents/2025_06_13_0021.abf',
#  'data/7-Synaptic_currents/2025_06_13_0022_100hz.abf',
#  'data/7-Synaptic_currents/2025_06_13_0019.abf',
#  'data/7-Synaptic_currents/2025_06_13_0018.abf',
#  'data/7-Synaptic_currents/2025_06_13_0023_100hz.abf',
#  'data/7-Synaptic_currents/2025_06_13_0016.abf',
#  'data/7-Synaptic_currents/2025_06_13_0017.abf',
#  'data/7-Synaptic_currents/2025_06_13_0015.abf',
#  'data/7-Synaptic_currents/2025_06_13_0012.abf']

# %% [markdown]
# Choose which file you want to analyze (copy name from above) and paste the file name here:

# %%
# data_file = 'data/7-Synaptic_currents/2025_06_13_0021.abf'
data_file = 'data/7-Synaptic_currents/2025_06_13_0019.abf'

# %% [markdown]
# Now we can load the file and plot the raw data:

# %%
traces = Trace.from_axon_file(filename=data_file, 
                              load_voltage=True, 
                              load_ttl=True,
                              units=['pA', 'mV', 'V'], 
                              concatenate_sweeps=False)
print(traces)

time_units = 'ms' # specify seconds (s), or milliseconds (ms)

# ----------------------------------------------------------------------------------------------------------------
# %matplotlib inline
traces.plot(plot_ttl=True, plot_voltage=False, sweep='all', time_units=time_units)
# ax1,ax2 = traces.plot(plot_ttl=False, plot_voltage=False, sweep='all', time_units='ms')
# ax1.set_xlim(20,50)
plt.show()
# Out:
# Trace('2025_06_13_0019.abf')
# ...
# Number of sweeps: 10
# Points per sweep: 20,000
# Duration per sweep: 2.000 s
# Sampling rate: 10000 Hz
# Sampling interval: 0.100 ms
# Available channels: Current, Voltage, TTL

# %% [markdown]
# ## 2. Signal processing

# %% [markdown]
# ### Baseline the trace and apply highpass / lowpass / bandpass filtering
#
# We want to measure the current amplitude relative to the baseline before the stimulus starts.
#
# Depending on you recording, you may also have 50/60 Hz line noise, high-frequency noise, or slow drift in your recording that we can correct for.

# %% [markdown]
# You can run this next cell as many times as you want to fine-tune the filtering parameters:

# %%
subtract_baseline = True    # Subtract baseline to measure the current relative to the baseline (just before the voltage step)

linear_detrending = False   # Detrend the data to remove linear or constant trends (e.g slow drift)
lowpass_filter    = False  # Lowpass filter (removes high-frequency noise)
bandpass_filter   = False   # Bandpass filter (removes 50/60 Hz mainline noise)


# ----------------------------------------------------------------------------------------------------------------
filtered_traces = traces.copy()
if linear_detrending:
    # Detrend the data to remove linear or constant trends (e.g slow drift)
    filtered_traces = filtered_traces.detrend(detrend_type='linear', num_segments=1, apply_to_voltage=False)

if lowpass_filter:
    # Lowpass filter (removes high-frequency noise)
    filtered_traces = filtered_traces.lowpass_filter(cutoff_freq = 4000) # Choose a value in units of Hz
    
if bandpass_filter:
    # Bandpass filter (removes 50/60 Hz mainline noise)
    filtered_traces = filtered_traces.filter_line_noise(
        line_freq = 60, # Frequency (Hz) of noise to remove: 50 Hz (in Europe) or 60 Hz (in the US).
        width = 1, # Width (Hz) controls the width of frequency bands around the line frequency the filter cuts out.
        method = 'notch') # Options: 'notch' (IIR notch filter), 'bandstop' (Butterworth), or 'fft' (spectral).

if subtract_baseline:
    start_baseline = 0  # Start time for baseline subtraction
    end_baseline = 10  # End time for baseline subtraction
    filtered_traces.subtract_baseline(start_time = start_baseline, end_time = end_baseline , time_units = time_units, channel = 'current')

# Plot the traces before and after filtering
if any([linear_detrending, lowpass_filter, bandpass_filter, subtract_baseline]):
    # %matplotlib widget
    # %matplotlib inline
    ax = traces.plot(plot_voltage=False, time_units=time_units, sweep='all')
    ax.set_title('Raw data', y=0.98)
    ylims = ax.get_ylim()
    plt.show()
    ax = filtered_traces.plot(plot_voltage=False, time_units=time_units, sweep='all')
    ax.set_title('After filtering', y=0.98)
    ax.set_ylim(ylims)
    plt.show()
# Out:
# BASELINE SUBTRACTED:
# Baseline currents (pA): [-368.6584 -419.7998 -470.4163 ... -537.6404 -545.6787 -552.3743]

# %% [markdown]
# Once you are happy with the filter setting, run the next cell to implement them:

# %%
if any([linear_detrending, lowpass_filter, bandpass_filter, subtract_baseline]):
    print("Applied filtering and/or baseline subtraction to the traces.")
    traces = filtered_traces
# Out:
# Applied filtering and/or baseline subtraction to the traces.

# %% [markdown]
# ## 3. Measure EPSCs/IPSCs to get paired pulse ratio
#
# (If you want to save images, click on the save icon on the left when you hover over the image)

# %% [markdown]
# ### 3.1. Get the single-stim response

# %%
# Find positive current peaks above threshold
stim_times = traces.get_event_times(threshold=-2000, 
                                    polarity='negative', 
                                    time_units=time_units, 
                                    channel='current', sweep='all')
stim_times = np.array(stim_times) + 0.1
print(f"Stim times:")
print(stim_times)
# Out:
# Stim times:
# [[  31.5 1032.5 1083.5]
#  [  31.5 1032.5 1133.5]
#  [  31.5 1032.5 1183.5]
#  ...
#  [  31.5 1032.5 1433.5]
#  [  31.5 1032.5 1483.5]
#  [  31.5 1032.5 1533.5]]

# %%
window_size = 600 #ms

single_stim_traces = traces.crop(timepoint=stim_times[0][0], window=window_size, time_units=time_units)
ax = single_stim_traces.plot(plot_voltage=False, plot_ttl=False, time_units=time_units, sweep='all')
ax.set_title('Single stim',y=0.95)

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Optional: remove bad traces

# %%
remove_spikes = False

# ---------------------------------------------------------------------------------------------------------
if remove_spikes:
    # Remove sweeps with positive current spikes above or below threshold
    info = single_stim_traces.remove_sweeps_with_spikes(threshold=-2000, polarity='negative', 
                                                channel='current', return_info=True)

    ax = single_stim_traces.plot(plot_voltage=False, plot_ttl=False, time_units=time_units, sweep='all')
    # ax.set_ylim(bottom=-600, top=100)
    ax.set_title('Single stim (spikes removed)',y=0.95)
    plt.show()

# %% [markdown]
# #### Measure single-stim amplitudes

# %%
single_stim_currents, _ = single_stim_traces.get_measurements(start_time=4, 
                                                            end_time=15, 
                                                            measurement_type='min', 
                                                            time_units=time_units)
# %matplotlib inline
fig,ax = plt.subplots(figsize=(8,3))
x = range(len(single_stim_currents))
ax.plot(x, single_stim_currents, '-o', color='black')
ax.set_ylabel('Single-stim currents (pA)')
ax.set_xlabel("Sweep nr.")
plt.show()

# %% [markdown]
# ### 3.2. Get the response to the first paired-pulse stim

# %%
smallest_interval = stim_times[0][2] - stim_times[0][1] - 0.1
first_pulse_traces = traces.crop(timepoint=stim_times[0][1], window=smallest_interval, time_units=time_units)
# %matplotlib widget
ax = first_pulse_traces.plot(plot_voltage=False, plot_ttl=False, time_units=time_units, sweep='all')
ax.set_title('First paired-pulse stim',y=0.95)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# #### Optional: remove bad traces

# %%
remove_spikes = False

# ---------------------------------------------------------------------------------------------------------
if remove_spikes:
    # Remove sweeps with positive current spikes above or below threshold
    info = first_pulse_traces.remove_sweeps_with_spikes(threshold=-2000, polarity='negative', 
                                                channel='current', return_info=True)
    ax = first_pulse_traces.plot(plot_voltage=False, plot_ttl=False, time_units=time_units, sweep='all')
    # ax.set_ylim(bottom=-600, top=100)
    ax.set_title('First paired-pulse stim (spikes removed)',y=0.95)
    plt.show()

# %% [markdown]
# #### Measure first paired-pulse amplitudes

# %%
first_pulse_currents,_ = first_pulse_traces.get_measurements(start_time=2, 
                                                            end_time=15, 
                                                            measurement_type='min', 
                                                            time_units=time_units)
fig,ax = plt.subplots(figsize=(8,3))
ax.plot(first_pulse_currents, '-o', color='black')
ax.set_xticks(range(len(first_pulse_currents)))
ax.set_ylabel('first paired-pulse currents (pA)')
ax.set_xlabel("sweep nr.")
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# ### 3.3. Get the response to the second paired-pulse stim

# %% [markdown]
# #### Subtract single-stim response from paired-pulse trace
#
# This allows us to recover the shape/amplitude of the second pulse, without the contribution of the first pulse

# %%
paired_pulse_traces = traces.crop(timepoint=stim_times[0][1], window=window_size, time_units='ms')
ax = paired_pulse_traces.plot(plot_voltage=False, plot_ttl=False, time_units=time_units, sweep='all')
ax.set_title('Paired stim',y=0.95)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Now we will get the average "first stim" response and subtract it from all of the paired-pulse sweeps

# %%
subtracted_traces = paired_pulse_traces.copy()
subtract_average_single_stim = False  # We can either subtract the average single-stim, or subtract each individual single-stim (from every sweep)

if subtract_average_single_stim:
    avg_single_stim_trace = np.mean(single_stim_traces.current_data, axis=0)
    len1 = avg_single_stim_trace.shape[0]
    len2 = subtracted_traces.current_data.shape[1]
    if len1<len2:
        subtracted_traces.current_data = subtracted_traces.current_data[:,:len1]
    elif len2<len1:
        avg_single_stim_trace = avg_single_stim_trace[:len2]
    subtracted_traces.current_data -= avg_single_stim_trace
else:
    len1 = single_stim_traces.current_data.shape[1]
    len2 = subtracted_traces.current_data.shape[1]
    if len1<len2:
        subtracted_traces.current_data = subtracted_traces.current_data[:,:len1]
    elif len2<len1:
        avg_single_stim_trace = avg_single_stim_trace[:,:len2]
    subtracted_traces.current_data -= single_stim_traces.current_data

ax = subtracted_traces.plot(plot_voltage=False, plot_ttl=False, time_units=time_units, sweep='all')
ax.set_title('After subtraction',y=0.95)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# Now we need to isolate the second pulse

# %%
# Find positive current peaks above threshold
stim_times = subtracted_traces.get_event_times(threshold=-2000, 
                                            polarity='negative', 
                                            time_units=time_units, 
                                            channel='current', sweep='all')
print(f"Stim times:")
stim_times
# Out:
# Stim times:
# [array([50.9]),
#  array([100.9]),
#  array([150.9]),
#  array([200.9]),
#  array([250.9]),
#  array([300.9]),
#  array([350.9]),
#  array([400.9]),
#  array([450.9]),
#  array([500.9])]

# %% [markdown]
# #### Measure second paired-pulse amplitudes

# %%
second_pulse_currents = []
for i, stim_time in enumerate(stim_times):
    current,_ = subtracted_traces.get_measurements(sweep=i, measurement_type='min', time_units=time_units,
                                                   start_time=stim_time+2, end_time=stim_time+15)
    second_pulse_currents.append(current)

# %matplotlib inline
fig,ax = plt.subplots(figsize=(8,3))
x = range(len(second_pulse_currents))
ax.plot(x, second_pulse_currents, '-o', color='black')
ax.set_ylabel('Second paired-pulse \ncurrents (pA)')
ax.set_xlabel("Sweep nr.")
plt.show()

# %% [markdown]
# ### 3.4. Plot paired-pulse ratio

# %%
if len(first_pulse_currents) == len(second_pulse_currents):
    paired_pulse_ratios = second_pulse_currents / first_pulse_currents
    avg_ppr = np.mean(paired_pulse_ratios)
    fig,ax = plt.subplots()
    ax.plot(paired_pulse_ratios, '-o', color='black')
    ax.set_xticks(range(len(second_pulse_currents)))
    xlims = ax.get_xlim()
    ax.set_ylim(bottom=0)
    ax.hlines(1, xlims[0],xlims[1],linestyle='--',color='gray')
    ax.text(0, 0.5, f"Average paired-pulse ratio: {avg_ppr:.2f}", fontsize=12, ha='left', va='bottom')
    ax.set_ylabel('Paired-pulse ratio \n(EPSC 2 / EPSC 1)')
    ax.set_xlabel("$\Delta t$ (ms)")
    plt.show()
else:
    avg_second_pulse = np.mean(second_pulse_currents)
    avg_first_pulse = np.mean(first_pulse_currents)
    paired_pulse_ratio = avg_second_pulse / avg_first_pulse
    print(f"Paired-pulse ratio: {paired_pulse_ratio}")
